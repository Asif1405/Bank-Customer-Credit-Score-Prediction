# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\MSI\\Desktop\\Credit Score\\cs-training.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
df.shape
# Out:
# (150000, 12)

# %%
df.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
# Unnamed: 0                              150000 non-null int64
# SeriousDlqin2yrs                        150000 non-null int64
# RevolvingUtilizationOfUnsecuredLines    150000 non-null float64
# age                                     150000 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    150000 non-null int64
# DebtRatio                               150000 non-null float64
# MonthlyIncome                           120269 non-null float64
# NumberOfOpenCreditLinesAndLoans         150000 non-null int64
# NumberOfTimes90DaysLate                 150000 non-null int64
# NumberRealEstateLoansOrLines            150000 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    150000 non-null int64
# NumberOfDependents                      146076 non-null float64
# dtypes: float64(4), int64(8)
# memory usage: 13.7 MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                  0
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(df['SeriousDlqin2yrs'], palette='Set2')

# %%
from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
default_df = df.loc[df['SeriousDlqin2yrs'] == 1]

# %%
default_df.shape
# Out:
# (10026, 12)

# %%
non_default_df = df.loc[df['SeriousDlqin2yrs'] == 0].sample(n=10026,random_state=42)

# %%
normalized_df = pd.concat([default_df,non_default_df])

# %%
normalized_df.shape
# Out:
# (20052, 12)

# %%
normalized_df.head()
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                 1                              0.766127   45
# 13          14                 1                              0.964673   40
# 21          22                 1                              0.025656   38
# 25          26                 1                              0.392248   50
# 51          52                 1                              0.728150   31
#
#     NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                      2   0.802982         9120.0
# 13                                     3   0.382965        13700.0
# 21                                     0   0.475841         3000.0
# 25                                     0   1.595253         4676.0
# 51                                     0   0.824725         3000.0
#
#     NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
sns.countplot(normalized_df['SeriousDlqin2yrs'], palette='Set2')

# %%
normalized_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20052 entries, 0 to 76224
# Data columns (total 12 columns):
# Unnamed: 0                              20052 non-null int64
# SeriousDlqin2yrs                        20052 non-null int64
# RevolvingUtilizationOfUnsecuredLines    20052 non-null float64
# age                                     20052 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    20052 non-null int64
# DebtRatio                               20052 non-null float64
# MonthlyIncome                           16414 non-null float64
# NumberOfOpenCreditLinesAndLoans         20052 non-null int64
# NumberOfTimes90DaysLate                 20052 non-null int64
# NumberRealEstateLoansOrLines            20052 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    20052 non-null int64
# NumberOfDependents                      19615 non-null float64
# dtypes: float64(4), int64(8)
# memory usage: 2.6 MB

# %%
normalized_df.isnull().sum()
# Out:
# Unnamed: 0                                 0
# SeriousDlqin2yrs                           0
# RevolvingUtilizationOfUnsecuredLines       0
# age                                        0
# NumberOfTime30-59DaysPastDueNotWorse       0
# DebtRatio                                  0
# MonthlyIncome                           3638
# NumberOfOpenCreditLinesAndLoans            0
# NumberOfTimes90DaysLate                    0
# NumberRealEstateLoansOrLines               0
# NumberOfTime60-89DaysPastDueNotWorse       0
# NumberOfDependents                       437
# dtype: int64

# %%
normalized_df = normalized_df.fillna(normalized_df.mean())

# %%
normalized_df.isnull().sum()
# Out:
# Unnamed: 0                              0
# SeriousDlqin2yrs                        0
# RevolvingUtilizationOfUnsecuredLines    0
# age                                     0
# NumberOfTime30-59DaysPastDueNotWorse    0
# DebtRatio                               0
# MonthlyIncome                           0
# NumberOfOpenCreditLinesAndLoans         0
# NumberOfTimes90DaysLate                 0
# NumberRealEstateLoansOrLines            0
# NumberOfTime60-89DaysPastDueNotWorse    0
# NumberOfDependents                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'SeriousDlqin2yrs',
#        'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents'],
#       dtype='object')

# %%
num_columns = [
       'RevolvingUtilizationOfUnsecuredLines', 'age',
       'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
       'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
       'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
       'NumberOfDependents']

fig, axs = plt.subplots(5, 2, sharex=False, sharey=False, figsize=(20, 15))

counter = 0
for num_column in num_columns:
    
    trace_x = counter // 2
    trace_y = counter % 2
    
    axs[trace_x, trace_y].hist(df[num_column])
    
    axs[trace_x, trace_y].set_title(num_column)
    
    counter += 1

plt.show()

# %%
age_hist = df['age'].hist(by=df['SeriousDlqin2yrs'], bins=20, layout=(2,1))
age_hist[0].set_xlim((0,100))
age_hist[0].set_title('SeriousDlqin2yrs = 0')
age_hist[1].set_xlim((0,100))
age_hist[1].set_title('SeriousDlqin2yrs = 1')
# Out:
# Text(0.5, 1.0, 'SeriousDlqin2yrs = 1')

# %%
normalized_df['DebtRatio'].describe()
# Out:
# count    20052.000000
# mean       325.439537
# std       1278.772964
# min          0.000000
# 25%          0.183683
# 50%          0.389504
# 75%          0.865560
# max      61907.000000
# Name: DebtRatio, dtype: float64

# %%
normalized_df.DebtRatio.quantile([.975])
# Out:
# 0.975    3467.45
# Name: DebtRatio, dtype: float64

# %%
normalized_df[normalized_df['DebtRatio'] > 3489.025][['SeriousDlqin2yrs','MonthlyIncome']].describe()
# Out:
#        SeriousDlqin2yrs  MonthlyIncome
# count        491.000000     491.000000
# mean           0.490835    5858.667345
# std            0.500426    1386.734085
# min            0.000000       0.000000
# 25%            0.000000    6186.242293
# 50%            0.000000    6186.242293
# 75%            1.000000    6186.242293
# max            1.000000    6186.242293

# %%
normalized_df[(df['DebtRatio'] > 3489.025) & (normalized_df['SeriousDlqin2yrs'] == normalized_df['MonthlyIncome'])].shape[0]
# Out:
# C:\Users\MSI\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 14

# %%
normalized_df.groupby('NumberOfTimes90DaysLate').NumberOfTimes90DaysLate.count()
# Out:
# NumberOfTimes90DaysLate
# 0     16236
# 1      2007
# 2       834
# 3       402
# 4       202
# 5        86
# 6        51
# 7        31
# 8        16
# 9        14
# 10        5
# 11        3
# 12        1
# 13        2
# 14        1
# 15        1
# 17        1
# 96        4
# 98      155
# Name: NumberOfTimes90DaysLate, dtype: int64

# %%
normalized_df[normalized_df['NumberOfTimes90DaysLate'] > 95][['SeriousDlqin2yrs','NumberOfTime60-89DaysPastDueNotWorse','NumberOfTime30-59DaysPastDueNotWorse','NumberOfTimes90DaysLate']].describe()
# Out:
#        SeriousDlqin2yrs  NumberOfTime60-89DaysPastDueNotWorse  \
# count        159.000000                            159.000000
# mean           0.924528                             97.949686
# std            0.264986                              0.314195
# min            0.000000                             96.000000
# 25%            1.000000                             98.000000
# 50%            1.000000                             98.000000
# 75%            1.000000                             98.000000
# max            1.000000                             98.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse  NumberOfTimes90DaysLate
# count                            159.000000               159.000000
# mean                              97.949686                97.949686
# std                                0.314195                 0.314195
# min                               96.000000                96.000000
# ...

# %%
normalized_df[(normalized_df['RevolvingUtilizationOfUnsecuredLines'] > .9) & (normalized_df['RevolvingUtilizationOfUnsecuredLines'] <= 4)].SeriousDlqin2yrs.describe()
# Out:
# count    5564.000000
# mean        0.802121
# std         0.398436
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: SeriousDlqin2yrs, dtype: float64

# %%
normalized_df[(normalized_df['RevolvingUtilizationOfUnsecuredLines'] > 4) & (normalized_df['RevolvingUtilizationOfUnsecuredLines'] <= 10)].SeriousDlqin2yrs.describe()
# Out:
# count    10.000000
# mean      0.600000
# std       0.516398
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: SeriousDlqin2yrs, dtype: float64

# %%
normalized_df[normalized_df['RevolvingUtilizationOfUnsecuredLines'] > 10].describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count      27.000000         27.000000                             27.000000
# mean    66843.037037          0.629630                           2508.653347
# std     49595.359952          0.492103                           2541.023938
# min       698.000000          0.000000                             11.385230
# 25%     23895.500000          0.000000                            169.291667
# 50%     63878.000000          1.000000                           2066.000000
# 75%    107539.000000          1.000000                           3623.000000
# max    149246.000000          1.000000                           9193.000000
#
#              age  NumberOfTime30-59DaysPastDueNotWorse     DebtRatio  \
# count  27.000000                             27.000000     27.000000
# mean   45.888889                              0.703704   1150.155577
# ...

# %%
# Median Fill, Outliers Removed
removed_debt_outliers = normalized_df.drop(normalized_df[normalized_df['DebtRatio'] > 3489.025].index)

# %%
removed_debt_outliers = removed_debt_outliers.fillna(removed_debt_outliers.median())

# %%
# Removed utilization outliers
dfus = removed_debt_outliers.drop(removed_debt_outliers[removed_debt_outliers['RevolvingUtilizationOfUnsecuredLines'] > 10].index)

# %%
# Removed 98s
dfn98 = dfus.copy()
dfn98.loc[dfn98['NumberOfTime30-59DaysPastDueNotWorse'] > 90, 'NumberOfTime30-59DaysPastDueNotWorse'] = 18
dfn98.loc[dfn98['NumberOfTime60-89DaysPastDueNotWorse'] > 90, 'NumberOfTime60-89DaysPastDueNotWorse'] = 18
dfn98.loc[dfn98['NumberOfTimes90DaysLate'] > 90, 'NumberOfTimes90DaysLate'] = 18

# %%
dfn98.shape
# Out:
# (19536, 12)

# %%
final_df = dfn98

# %%
final_df.columns
# Out:
# Index(['Unnamed: 0', 'SeriousDlqin2yrs',
#        'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents'],
#       dtype='object')

# %%
final_df = final_df.drop(["Unnamed: 0"], axis = 1)

# %%
final_df.head()
# Out:
#     SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                  1                              0.766127   45
# 13                 1                              0.964673   40
# 21                 1                              0.025656   38
# 25                 1                              0.392248   50
# 51                 1                              0.728150   31
#
#     NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                      2   0.802982         9120.0
# 13                                     3   0.382965        13700.0
# 21                                     0   0.475841         3000.0
# 25                                     0   1.595253         4676.0
# 51                                     0   0.824725         3000.0
#
#     NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                                13                        0
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19536 entries, 0 to 76224
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        19536 non-null int64
# RevolvingUtilizationOfUnsecuredLines    19536 non-null float64
# age                                     19536 non-null int64
# NumberOfTime30-59DaysPastDueNotWorse    19536 non-null int64
# DebtRatio                               19536 non-null float64
# MonthlyIncome                           19536 non-null float64
# NumberOfOpenCreditLinesAndLoans         19536 non-null int64
# NumberOfTimes90DaysLate                 19536 non-null int64
# NumberRealEstateLoansOrLines            19536 non-null int64
# NumberOfTime60-89DaysPastDueNotWorse    19536 non-null int64
# NumberOfDependents                      19536 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 1.8 MB

# %%
numerical_features = final_df.select_dtypes([np.number]).columns.tolist()
categorical_features = final_df.select_dtypes(exclude = [np.number,np.datetime64]).columns.tolist()

# %%
fig, ax = plt.subplots(5, 2, figsize=(30, 35))
for variable, subplot in zip(numerical_features, ax.flatten()):
    sns.regplot(x=final_df[variable], y=final_df['SeriousDlqin2yrs'], ax=subplot)

# %%
#Default and Due
def_df = pd.DataFrame()

def_df['yes'] = final_df[final_df['SeriousDlqin2yrs'] == 1]['NumberOfTime30-59DaysPastDueNotWorse'].value_counts()
def_df['no'] = final_df[final_df['SeriousDlqin2yrs'] == 0]['NumberOfTime30-59DaysPastDueNotWorse'].value_counts()

def_df.plot.bar(title = 'Default and Due 30-59')

# %%
#C
def_df = pd.DataFrame()

def_df['yes'] = final_df[final_df['SeriousDlqin2yrs'] == 1]['NumberOfTime60-89DaysPastDueNotWorse'].value_counts()
def_df['no'] = final_df[df['SeriousDlqin2yrs'] == 0]['NumberOfTime60-89DaysPastDueNotWorse'].value_counts()

def_df.plot.bar(title = 'Default and Due 60-89')
# Out:
# C:\Users\MSI\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
#Default and Due
def_df = pd.DataFrame()

def_df['yes'] = final_df[final_df['SeriousDlqin2yrs'] == 1]['NumberOfOpenCreditLinesAndLoans'].value_counts()
def_df['no'] = final_df[df['SeriousDlqin2yrs'] == 0]['NumberOfOpenCreditLinesAndLoans'].value_counts()

def_df.plot.bar(title = 'Job and deposit')
# Out:
# C:\Users\MSI\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
#Default and bnumber of dependents
def_df = pd.DataFrame()

def_df['yes'] = final_df[final_df['SeriousDlqin2yrs'] == 1]['NumberOfDependents'].value_counts()
def_df['no'] = final_df[df['SeriousDlqin2yrs'] == 0]['NumberOfDependents'].value_counts()

def_df.plot.bar(title = 'Default and bnumber of dependents')
# Out:
# C:\Users\MSI\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
#Default and real state
def_df = pd.DataFrame()

def_df['yes'] = final_df[final_df['SeriousDlqin2yrs'] == 1]['NumberRealEstateLoansOrLines'].value_counts()
def_df['no'] = final_df[df['SeriousDlqin2yrs'] == 0]['NumberRealEstateLoansOrLines'].value_counts()

def_df.plot.bar(title = 'Default and real state')
# Out:
# C:\Users\MSI\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
#Default and Due
def_df = pd.DataFrame()

def_df['yes'] = final_df[final_df['SeriousDlqin2yrs'] == 1]['NumberOfTimes90DaysLate'].value_counts()
def_df['no'] = final_df[df['SeriousDlqin2yrs'] == 0]['NumberOfTimes90DaysLate'].value_counts()

def_df.plot.bar(title = 'Default and Due 90 days')
# Out:
# C:\Users\MSI\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
x = final_df.drop(["SeriousDlqin2yrs"], axis = 1)
y = final_df["SeriousDlqin2yrs"]

# %%
x.shape
# Out:
# (19536, 10)

# %%
y.shape
# Out:
# (19536,)

# %%
import xgboost

# %%
xgb = xgboost.XGBClassifier(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)
xgb.fit(x,y.squeeze().values)

headers = ["name", "score"]
values = sorted(zip(x.columns, xgb.feature_importances_), key=lambda x: x[1] * -1)
xgb_feature_importances = pd.DataFrame(values, columns = headers)

#plot feature importances
x_pos = np.arange(0, len(xgb_feature_importances))
plt.bar(x_pos, xgb_feature_importances['score'])
plt.xticks(x_pos, xgb_feature_importances['name'])
plt.xticks(rotation=90)
plt.title('Feature importances (XGB)')

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler as ss
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier

# %%
corr = final_df.corrwith(final_df["SeriousDlqin2yrs"]).plot.bar(title = "Correlation", fontsize = 10, rot = 90, grid = True)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state= 0)

# %%
#logistic Regression
lr = LogisticRegression()
lr.fit(x_train, y_train)
print('Test Accuracy {:.2f}%'.format(lr.score(x_test, y_test)*100))
# Out:
# Test Accuracy 75.99%
# C:\Users\MSI\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
#KNN model
from sklearn.neighbors import KNeighborsClassifier
knn =  KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train, y_train)
print("KNN accuracy: {:.2f}%".format(knn.score(x_test, y_test)*100))
# Out:
# KNN accuracy: 57.57%

# %%
# support vector
svm = SVC(random_state = 1, gamma = "auto")
svm.fit(x_train, y_train)
print("SVC accuracy: {:.2f}%".format(svm.score(x_test, y_test)*100))
# Out:
# SVC accuracy: 55.45%

# %%
nb = GaussianNB()
nb.fit(x_train, y_train)
print("NB accuracy: {:.2f}%".format(nb.score(x_test, y_test)*100))
# Out:
# NB accuracy: 67.41%

# %%
rf = RandomForestClassifier(n_estimators = 1000, random_state= 1)
rf.fit(x_train, y_train)
print("Random Forest accuracy: {:.2f}%".format(rf.score(x_test, y_test)*100))
# Out:
# Random Forest accuracy: 78.11%

# %%
#train XGBoost model
xgb = xgboost.XGBClassifier(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)
xgb.fit(x_train,y_train.squeeze().values)

#calculate and print scores for the model for top 15 features
y_train_preds = xgb.predict(x_train)
y_test_preds = xgb.predict(x_test)

print('XGB accuracy score for train: %.3f: test: %.3f' % (
        accuracy_score(y_train, y_train_preds),
        accuracy_score(y_test, y_test_preds)))
# Out:
# XGB accuracy score for train: 0.841: test: 0.789
